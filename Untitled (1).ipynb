# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
im1=mpimg.imread('DSC_0997.JPG')
im2=mpimg.imread('DSCPDC_0001_BURST20190321154833380.JPG')
im3=mpimg.imread('DSC_0998.JPG')
im4=mpimg.imread('DSC_0999.JPG')
im5=mpimg.imread('DSC_1000.JPG')
plt.imshow(im1)
plt.imshow(im2)

# %%
b_im1=im1[:,:,2]
b_im2=im2[:,:,2]
b_im=np.stack((b_im1,b_im2))
print(b_im)
# Out:
# [[[136 136 138 ...  10  11  12]
#   [136 135 137 ...  13  11  12]
#   [135 134 137 ...  14  14  14]
#   ...
#   [127 127 127 ...  26  23  27]
#   [127 127 126 ...  25  25  24]
#   [126 128 127 ...  24  27  25]]
#
#  [[ 41  39  39 ...  13  13  11]
#   [ 37  37  37 ...  13  14  13]
#   [ 33  34  35 ...  13  13  12]
#   ...
#   [147 146 145 ...  41  40  40]
#   [150 147 147 ...  43  43  41]
#   [152 152 152 ...  41  40  38]]]

# %%
b_ave=np.mean(b_im,axis=0)
plt.imshow(b_ave)
plt.axis('off')
plt.savefig('phantom.JPG',bbox_inches='tight',pad_inches=0)

# %%
ims=np.stack((im1,im2,im3,im4,im5))
ims_ave=np.mean(ims,axis=0)
plt.imshow(ims_ave.astype(int))
